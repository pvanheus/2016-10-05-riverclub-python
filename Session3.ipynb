# %%
import pandas

# %%
data = pandas.read_csv('data/gapminder_gdp_oceania.csv', index_col='country')

# %%
data
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
data.info()
# note this is not the same as data.info without the brackets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, Australia to New Zealand
# Data columns (total 12 columns):
# gdpPercap_1952    2 non-null float64
# gdpPercap_1957    2 non-null float64
# gdpPercap_1962    2 non-null float64
# gdpPercap_1967    2 non-null float64
# gdpPercap_1972    2 non-null float64
# gdpPercap_1977    2 non-null float64
# gdpPercap_1982    2 non-null float64
# gdpPercap_1987    2 non-null float64
# gdpPercap_1992    2 non-null float64
# gdpPercap_1997    2 non-null float64
# gdpPercap_2002    2 non-null float64
# gdpPercap_2007    2 non-null float64
# dtypes: float64(12)
# memory usage: 208.0+ bytes

# %%
data.columns
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
print(type(data.columns))
# Out:
# <class 'pandas.indexes.base.Index'>

# %%
print(data.T)
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
data.T
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
data.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# ...

# %%
data
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
data.t
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-cd8b0ae7da60> in <module>()
# ----> 1 data.t
#
# /home/pvh/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 't'

# %%
data.T
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
africa_data = pandas.read_csv('data/gapminder_gdp_africa.csv', index_col='country')

# %%
africa_data.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       52.000000       52.000000       52.000000       52.000000
# mean      1252.572466     1385.236062     1598.078825     2050.363801
# std        982.952116     1134.508918     1461.839189     2847.717603
# min        298.846212      335.997115      355.203227      412.977514
# 25%        534.990554      606.954355      673.329046      779.815648
# 50%        987.025569     1024.022987     1133.783677     1210.376379
# 75%       1454.886645     1573.040442     1702.219247     1890.112274
# max       4725.295531     5487.104219     6757.030816    18772.751690
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       52.000000       52.000000       52.000000       52.000000
# mean      2339.615674     2585.938508     2481.592960     2282.668991
# std       3286.853884     4142.398707     3242.632753     2566.531947
# ...

# %%
africa_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, Algeria to Zimbabwe
# Data columns (total 12 columns):
# gdpPercap_1952    52 non-null float64
# gdpPercap_1957    52 non-null float64
# gdpPercap_1962    52 non-null float64
# gdpPercap_1967    52 non-null float64
# gdpPercap_1972    52 non-null float64
# gdpPercap_1977    52 non-null float64
# gdpPercap_1982    52 non-null float64
# gdpPercap_1987    52 non-null float64
# gdpPercap_1992    52 non-null float64
# gdpPercap_1997    52 non-null float64
# gdpPercap_2002    52 non-null float64
# gdpPercap_2007    52 non-null float64
# dtypes: float64(12)
# memory usage: 5.3+ KB

# %%
africa_data[:3]
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Algeria     2449.008185     3013.976023     2550.816880     3246.991771
# Angola      3520.610273     3827.940465     4269.276742     5522.776375
# Benin       1062.752200      959.601080      949.499064     1035.831411
#
#          gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Algeria     4182.663766     4910.416756     5745.160213     5681.358539
# Angola      5473.288005     3008.647355     2756.953672     2430.208311
# Benin       1085.796879     1029.161251     1277.897616     1225.856010
#
#          gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Algeria     5023.216647     4797.295051     5288.040382     6223.367465
# Angola      2627.845685     2277.140884     2773.287312     4797.231267
# Benin       1191.207681     1232.975292     1372.877931     1441.284873

# %%
africa_data.T[:3]
# Out:
# country             Algeria       Angola        Benin    Botswana  \
# gdpPercap_1952  2449.008185  3520.610273  1062.752200  851.241141
# gdpPercap_1957  3013.976023  3827.940465   959.601080  918.232535
# gdpPercap_1962  2550.816880  4269.276742   949.499064  983.653976
#
# country         Burkina Faso     Burundi     Cameroon  \
# gdpPercap_1952    543.255241  339.296459  1172.667655
# gdpPercap_1957    617.183465  379.564628  1313.048099
# gdpPercap_1962    722.512021  355.203227  1399.607441
#
# country         Central African Republic         Chad      Comoros  \
# gdpPercap_1952               1071.310713  1178.665927  1102.990936
# gdpPercap_1957               1190.844328  1308.495577  1211.148548
# gdpPercap_1962               1193.068753  1389.817618  1406.648278
#
# country            ...          Somalia  South Africa        Sudan  \
# gdpPercap_1952     ...      1135.749842   4725.295531  1615.991129
# gdpPercap_1957     ...      1258.147413   5487.104219  1770.337074
# ...

# %%
africa_data.T[:3].describe()
# Out:
# country      Algeria       Angola        Benin    Botswana  Burkina Faso  \
# count       3.000000     3.000000     3.000000    3.000000      3.000000
# mean     2671.267029  3872.609160   990.617448  917.709217    627.650242
# std       301.128450   376.326772    62.674393   66.207969     90.085589
# min      2449.008185  3520.610273   949.499064  851.241141    543.255241
# 25%      2499.912532  3674.275369   954.550072  884.736838    580.219353
# 50%      2550.816880  3827.940465   959.601080  918.232535    617.183465
# 75%      2782.396451  4048.608603  1011.176640  950.943256    669.847743
# max      3013.976023  4269.276742  1062.752200  983.653976    722.512021
#
# country     Burundi     Cameroon  Central African Republic         Chad  \
# count      3.000000     3.000000                  3.000000     3.000000
# mean     358.021438  1295.107732               1151.741265  1292.326374
# std       20.281472   114.528639                 69.663780   106.500430
# ...

# %%
africa_data.T[:3].to_csv('data/africa_subset.csv')

# %%
africa_data.ix['Algeria']
# Out:
# gdpPercap_1952    2449.008185
# gdpPercap_1957    3013.976023
# gdpPercap_1962    2550.816880
# gdpPercap_1967    3246.991771
# gdpPercap_1972    4182.663766
# gdpPercap_1977    4910.416756
# gdpPercap_1982    5745.160213
# gdpPercap_1987    5681.358539
# gdpPercap_1992    5023.216647
# gdpPercap_1997    4797.295051
# gdpPercap_2002    5288.040382
# gdpPercap_2007    6223.367465
# Name: Algeria, dtype: float64

# %%
africa_data.ix['Algeria':'Benin', 'gdpPercap_1952']
# Out:
# country
# Algeria    2449.008185
# Angola     3520.610273
# Benin      1062.752200
# Name: gdpPercap_1952, dtype: float64

# %%
africa_data.ix['Algeria':'Benin', 'gdpPercap_1952':'gdpPercap_1962']
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962
# country
# Algeria     2449.008185     3013.976023     2550.816880
# Angola      3520.610273     3827.940465     4269.276742
# Benin       1062.752200      959.601080      949.499064

# %%
africa_data.ix['Algeria':'Benia', 'gdpPercap_1952':'gdpPercap_1962']
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962
# country
# Algeria     2449.008185     3013.976023     2550.816880
# Angola      3520.610273     3827.940465     4269.276742

# %%
# if you want to slice multiple dimensions of your dataframe, use .ix[]
africa_data['Algeria':'Benin', 'gdpPercap_1952':'gdpPercap_1962']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-b1d92cab671e> in <module>()
# ----> 1 africa_data['Algeria':'Benin', 'gdpPercap_1952':'gdpPercap_1962']
#
# /home/pvh/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /home/pvh/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /home/pvh/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
# ...

# %%
# all rows for the first column
africa_data.ix[:, 'gdpPercap_1952']
# Out:
# country
# Algeria                     2449.008185
# Angola                      3520.610273
# Benin                       1062.752200
# Botswana                     851.241141
# Burkina Faso                 543.255241
# Burundi                      339.296459
# Cameroon                    1172.667655
# Central African Republic    1071.310713
# Chad                        1178.665927
# Comoros                     1102.990936
# Congo Dem. Rep.              780.542326
# Congo Rep.                  2125.621418
# Cote d'Ivoire               1388.594732
# Djibouti                    2669.529475
# Egypt                       1418.822445
# Equatorial Guinea            375.643123
# Eritrea                      328.940557
# Ethiopia                     362.146280
# Gabon                       4293.476475
# Gambia                       485.230659
# Ghana                        911.298937
# Guinea                       510.196492
# Guinea-Bissau                299.850319
# ...

# %%
africa_data.ix['Algeria':'Benin'].max()
# Out:
# gdpPercap_1952    3520.610273
# gdpPercap_1957    3827.940465
# gdpPercap_1962    4269.276742
# gdpPercap_1967    5522.776375
# gdpPercap_1972    5473.288005
# gdpPercap_1977    4910.416756
# gdpPercap_1982    5745.160213
# gdpPercap_1987    5681.358539
# gdpPercap_1992    5023.216647
# gdpPercap_1997    4797.295051
# gdpPercap_2002    5288.040382
# gdpPercap_2007    6223.367465
# dtype: float64

# %%
mask = africa_data > 3000

# %%
africa_data[mask]
# Out:
#                           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria                              NaN     3013.976023             NaN
# Angola                       3520.610273     3827.940465     4269.276742
# Benin                                NaN             NaN             NaN
# Botswana                             NaN             NaN             NaN
# Burkina Faso                         NaN             NaN             NaN
# Burundi                              NaN             NaN             NaN
# Cameroon                             NaN             NaN             NaN
# Central African Republic             NaN             NaN             NaN
# Chad                                 NaN             NaN             NaN
# Comoros                              NaN             NaN             NaN
# Congo Dem. Rep.                      NaN             NaN             NaN
# Congo Rep.                           NaN             NaN             NaN
# ...

# %%
africa_data[africa_data > 3000]
# Out:
#                           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria                              NaN     3013.976023             NaN
# Angola                       3520.610273     3827.940465     4269.276742
# Benin                                NaN             NaN             NaN
# Botswana                             NaN             NaN             NaN
# Burkina Faso                         NaN             NaN             NaN
# Burundi                              NaN             NaN             NaN
# Cameroon                             NaN             NaN             NaN
# Central African Republic             NaN             NaN             NaN
# Chad                                 NaN             NaN             NaN
# Comoros                              NaN             NaN             NaN
# Congo Dem. Rep.                      NaN             NaN             NaN
# Congo Rep.                           NaN             NaN             NaN
# ...

# %%
africa_data.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       52.000000       52.000000       52.000000       52.000000
# mean      1252.572466     1385.236062     1598.078825     2050.363801
# std        982.952116     1134.508918     1461.839189     2847.717603
# min        298.846212      335.997115      355.203227      412.977514
# 25%        534.990554      606.954355      673.329046      779.815648
# 50%        987.025569     1024.022987     1133.783677     1210.376379
# 75%       1454.886645     1573.040442     1702.219247     1890.112274
# max       4725.295531     5487.104219     6757.030816    18772.751690
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       52.000000       52.000000       52.000000       52.000000
# mean      2339.615674     2585.938508     2481.592960     2282.668991
# std       3286.853884     4142.398707     3242.632753     2566.531947
# ...

# %%
africa_data[africa_data > 3000].describe()
# Out:
# /home/pvh/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        3.000000        5.000000        7.000000        8.000000
# mean      4179.794093     4150.700640     4684.917814     6731.335100
# std        610.335486     1043.686513     1671.710304     5225.495475
# min       3520.610273     3013.976023     3020.989263     3020.050513
# 25%               NaN             NaN             NaN             NaN
# 50%               NaN             NaN             NaN             NaN
# 75%               NaN             NaN             NaN             NaN
# max       4725.295531     5487.104219     6757.030816    18772.751690
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       10.000000       13.000000       12.000000       12.000000
# ...

# %%
africa_data
# Out:
#                           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria                      2449.008185     3013.976023     2550.816880
# Angola                       3520.610273     3827.940465     4269.276742
# Benin                        1062.752200      959.601080      949.499064
# Botswana                      851.241141      918.232535      983.653976
# Burkina Faso                  543.255241      617.183465      722.512021
# Burundi                       339.296459      379.564628      355.203227
# Cameroon                     1172.667655     1313.048099     1399.607441
# Central African Republic     1071.310713     1190.844328     1193.068753
# Chad                         1178.665927     1308.495577     1389.817618
# Comoros                      1102.990936     1211.148548     1406.648278
# Congo Dem. Rep.               780.542326      905.860230      896.314634
# Congo Rep.                   2125.621418     2315.056572     2464.783157
# ...

# %%
africa_data.ix['Egypt', 'gdpPercap_1977']
# Out:
# 2785.4935820000001

# %%
data_from_1952 = africa_data.ix[:, 'gdpPercap_1952']
print("minimum gdp in 1952:", data_from_1952.min())
print("maximum gdp in 1952:", data_from_1952.max())
print("where did we find minimum gdp in 1952:", data_from_1952.idxmin())
print("where did we find maximum gdp in 1952:", data_from_1952.idxmax())
# Out:
# minimum gdp in 1952: 298.8462121
# maximum gdp in 1952: 4725.295531
# where did we find minimum gdp in 1952: Lesotho
# where did we find maximum gdp in 1952: South Africa

# %%
africa_data.idxmin()
# Out:
# gdpPercap_1952            Lesotho
# gdpPercap_1957            Lesotho
# gdpPercap_1962            Burundi
# gdpPercap_1967            Burundi
# gdpPercap_1972            Burundi
# gdpPercap_1977         Mozambique
# gdpPercap_1982         Mozambique
# gdpPercap_1987         Mozambique
# gdpPercap_1992         Mozambique
# gdpPercap_1997    Congo Dem. Rep.
# gdpPercap_2002    Congo Dem. Rep.
# gdpPercap_2007    Congo Dem. Rep.
# dtype: object

# %%
africa_data.idxmax()
# Out:
# gdpPercap_1952    South Africa
# gdpPercap_1957    South Africa
# gdpPercap_1962           Libya
# gdpPercap_1967           Libya
# gdpPercap_1972           Libya
# gdpPercap_1977           Libya
# gdpPercap_1982           Libya
# gdpPercap_1987           Gabon
# gdpPercap_1992           Gabon
# gdpPercap_1997           Gabon
# gdpPercap_2002           Gabon
# gdpPercap_2007           Gabon
# dtype: object

# %%
africa_data.ix['Gabon':'South Africa', 'gdpPercap_2007']
# Out:
# 13206.48452

# %%
africa_data.ix['South Africa', 'gdpPercap_2007']
# Out:
# 9269.6578079999999

# %%
help(africa_data.idxmin)
# Out:
# Help on method idxmin in module pandas.core.frame:
#
# idxmin(axis=0, skipna=True) method of pandas.core.frame.DataFrame instance
#     Return index of first occurrence of minimum over requested axis.
#     NA/null values are excluded.
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         0 or 'index' for row-wise, 1 or 'columns' for column-wise
#     skipna : boolean, default True
#         Exclude NA/null values. If an entire row/column is NA, the result
#         will be NA
#
#     Returns
#     -------
#     idxmin : Series
#
#     Notes
#     -----
#     This method is the DataFrame version of ``ndarray.argmin``.
#
#     See Also
#     --------
#     Series.idxmin

# %%
africa_data.idxmin(axis=1)
# Out:
# country
# Algeria                     gdpPercap_1952
# Angola                      gdpPercap_1997
# Benin                       gdpPercap_1962
# Botswana                    gdpPercap_1952
# Burkina Faso                gdpPercap_1952
# Burundi                     gdpPercap_1952
# Cameroon                    gdpPercap_1952
# Central African Republic    gdpPercap_2007
# Chad                        gdpPercap_1982
# Comoros                     gdpPercap_2007
# Congo Dem. Rep.             gdpPercap_2002
# Congo Rep.                  gdpPercap_1952
# Cote d'Ivoire               gdpPercap_1952
# Djibouti                    gdpPercap_1997
# Egypt                       gdpPercap_1952
# Equatorial Guinea           gdpPercap_1952
# Eritrea                     gdpPercap_1952
# Ethiopia                    gdpPercap_1952
# Gabon                       gdpPercap_1952
# Gambia                      gdpPercap_1952
# Ghana                       gdpPercap_1987
# Guinea                      gdpPercap_1952
# ...

# %%
africa_data.T.idxmin()
# Out:
# country
# Algeria                     gdpPercap_1952
# Angola                      gdpPercap_1997
# Benin                       gdpPercap_1962
# Botswana                    gdpPercap_1952
# Burkina Faso                gdpPercap_1952
# Burundi                     gdpPercap_1952
# Cameroon                    gdpPercap_1952
# Central African Republic    gdpPercap_2007
# Chad                        gdpPercap_1982
# Comoros                     gdpPercap_2007
# Congo Dem. Rep.             gdpPercap_2002
# Congo Rep.                  gdpPercap_1952
# Cote d'Ivoire               gdpPercap_1952
# Djibouti                    gdpPercap_1997
# Egypt                       gdpPercap_1952
# Equatorial Guinea           gdpPercap_1952
# Eritrea                     gdpPercap_1952
# Ethiopia                    gdpPercap_1952
# Gabon                       gdpPercap_1952
# Gambia                      gdpPercap_1952
# Ghana                       gdpPercap_1987
# Guinea                      gdpPercap_1952
# ...

# %%
africa_data.ix[:,'gdpPercap_1982']
# Out:
# country
# Algeria                      5745.160213
# Angola                       2756.953672
# Benin                        1277.897616
# Botswana                     4551.142150
# Burkina Faso                  807.198586
# Burundi                       559.603231
# Cameroon                     2367.983282
# Central African Republic      956.752991
# Chad                          797.908101
# Comoros                      1267.100083
# Congo Dem. Rep.               673.747818
# Congo Rep.                   4879.507522
# Cote d'Ivoire                2602.710169
# Djibouti                     2879.468067
# Egypt                        3503.729636
# Equatorial Guinea             927.825343
# Eritrea                       524.875849
# Ethiopia                      577.860747
# Gabon                       15113.361940
# Gambia                        835.809611
# Ghana                         876.032569
# Guinea                        857.250358
# Guinea-Bissau                 838.123967
# ...

# %%
africa_data.ix[:,'gdpPercap_1982':]
# Out:
#                           gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# Algeria                      5745.160213     5681.358539     5023.216647
# Angola                       2756.953672     2430.208311     2627.845685
# Benin                        1277.897616     1225.856010     1191.207681
# Botswana                     4551.142150     6205.883850     7954.111645
# Burkina Faso                  807.198586      912.063142      931.752773
# Burundi                       559.603231      621.818819      631.699878
# Cameroon                     2367.983282     2602.664206     1793.163278
# Central African Republic      956.752991      844.876350      747.905525
# Chad                          797.908101      952.386129     1058.064300
# Comoros                      1267.100083     1315.980812     1246.907370
# Congo Dem. Rep.               673.747818      672.774812      457.719181
# Congo Rep.                   4879.507522     4201.194937     4016.239529
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.plot(x, y)
plt.xlabel('Numbers')
plt.ylabel('Squares')

# %%
data
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
data.ix['Australia'].plot()
plt.xticks(rotation=90)
# Out:
# (array([  0.,   2.,   4.,   6.,   8.,  10.,  12.]),
#  <a list of 7 Text xticklabel objects>)

# %%
data.T.plot()
plt.xticks(rotation=90)
# Out:
# (array([  0.,   2.,   4.,   6.,   8.,  10.,  12.]),
#  <a list of 7 Text xticklabel objects>)

# %%
data.plot()
plt.xticks(rotation=90)
# Out:
# (array([ 0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  <a list of 6 Text xticklabel objects>)

# %%
plt.style.use('ggplot')
data.T.plot(kind='bar')
plt.xticks(rotation=90)
plt.ylabel('GDP per capita')

# %%
plt.style.use('ggplot')
data.T.plot()
plt.xticks(rotation=90)
plt.ylabel('GDP per capita')

# %%
plt.figure(500,500)
africa_data.T.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-9325ea97191e> in <module>()
# ----> 1 plt.figsize(500,500)
#       2 africa_data.T.plot()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'figsize'
